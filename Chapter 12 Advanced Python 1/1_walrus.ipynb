# %% [markdown]
# Walrus Operator

# %%
if (take_value := int(input("Enter Any Number: ")) > 10):
    print(" Number is greater than 10")
elif(take_value < 10):
    print(" Number is lower than 10")
# Out:
# Enter Any Number:  2
#  Number is lower than 10
