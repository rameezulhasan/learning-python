# %%
fruit = "grapes"

match fruit:
    case "mango":
        print("This is mango")
    case "banana":
        print("This is banana")
    case "apple":
        print("This is apple")
    case _:
        print("Unknown Fruit")
# Out:
# Unknown Fruit
