# %%
dict1 = {
    "name1" : "Rameez",
    "age1" : 20
}
dict2 = {
    "name2": "Haseeb",
    "age2" : 25
}
merge = dict1 | dict2
print(merge)
# Out:
# {'name1': 'Rameez', 'age1': 20, 'name2': 'Haseeb', 'age2': 25}

# %% [markdown]
# **With Keyword**

# %%
with(
    open("file.txt") as f1,
    open("file2.txt") as f2
)

#  You can multiple files open this way
