# %%
try: 
    number = int(input("Hey, Enter any number: "))
    print(number)
except Exception as e:
    print(e)
print("Thank You")
# Out:
# Hey, Enter any number:  hy
# invalid literal for int() with base 10: 'hy'
# 0
