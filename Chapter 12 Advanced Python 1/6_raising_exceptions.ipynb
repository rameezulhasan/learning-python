# %%
try:
    a = int(input("Enter a number: "))
    b = int(input("Enter second number: "))
    
    if (b == 0 ):
        raise ZeroDivisionError("Hey You cannot divide by 0. Our program not divide any number by 0")
    else:
        print(f" Divsion of {a} / {b} is {a/b}")
except Exception as e:
    print(e)
print ("thanks")
# Out:
# Enter a number:  20
# Enter second number:  0
# Hey You cannot divide by 0. Our program not divide by 0
# thanks
