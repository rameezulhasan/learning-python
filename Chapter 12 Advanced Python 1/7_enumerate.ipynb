# %%
l = [3, 45, 51, 78]

for index, item in enumerate(l):
    print(f"The item of index is {index} and number is {item}")
# Out:
# The item of index is 1 and number is 3
# The item of index is 2 and number is 45
# The item of index is 3 and number is 51
# The item of index is 4 and number is 78
