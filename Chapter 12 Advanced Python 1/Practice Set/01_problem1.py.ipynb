# %% [markdown]
# Write a program to open three files 1.txt, 2.txt and 3.txt if any these files are not
# present, a message without exiting the program must be printed prompting the same.

# %%
with(
    open("1.txt") as f1,
    open("2.txt") as f2,
    open("3.txt") as f3
):
    data1 = f1.read()
    data2 = f2.read()
    data3 = f3.read()
print(f"{data1} \n{data2} \n{data3}")
# Out:
# Hello How are you?
# I am text on 2 TXT file.

# %%
try:
    with open ("1.txt", "r")as f:
        print(f.read())
except Exception as e:
    print(e)

try:
    with open("4.txt", "r")as f:
        print(f.read())
except Exception as e:
    print(e)
# Out:
# How are you?
# [Errno 2] No such file or directory: '4.txt'
