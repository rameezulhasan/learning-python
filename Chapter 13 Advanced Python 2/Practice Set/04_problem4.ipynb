# %% [markdown]
# Write a program to find the maximum of the numbers in a list using the reduce
# function.

# %%
from functools import reduce
numbers = [111,2,4,9,5,66,7,56,987]
max_number = reduce(lambda a,b:a if a>b else b, numbers)
print(max_number)
# Out:
# 987
